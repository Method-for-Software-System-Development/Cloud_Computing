# %% [markdown]
# <a href="https://colab.research.google.com/github/Method-for-Software-System-Development/Cloud_Computing/blob/develop/cload_index%2Bsearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
DBLink = "https://cloud-project-5adfc-default-rtdb.europe-west1.firebasedatabase.app/"

# %%
# !pip install requests beautifulsoup4
# !pip install firebase
# !pip install -q gradio
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: firebase in /usr/local/lib/python3.11/dist-packages (4.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from firebase) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->firebase) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->firebase) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->firebase) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->firebase) (2025.4.26)

# %% [markdown]
# # Create index

# %%
url = 'https://mqtt.org/'

# %%
import requests
import re
from bs4 import BeautifulSoup
from nltk.stem import PorterStemmer
from firebase import firebase
import matplotlib.pyplot as plt
from urllib.parse import urljoin

# %%
# Get the data of the selected url
def fetch_page(url):
 response = requests.get(url)
 if response.status_code == 200:
  soup = BeautifulSoup(response.text, 'html.parser')
  return soup
 else:
  return None

# Create index of the loaded page
def index_words(soup):
  index = {}
  words = re.findall(r'(?!\d)\w+', soup.get_text())
  for word in words:
    word = word.lower()
    if word in index:
      index[word] += 1
    else:
      index[word] = 1
  return index

# Remove the stop words from the index
def remove_stop_words(index):
  stop_words = {'a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', 'her', 'here', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'i', 'if', 'in', 'into', 'is', 'isn', "isn't", 'it', "it's", 'its', 'itself', 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she's", 'should', "should've", 'shouldn', "shouldn't", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', 'were', 'weren', "weren't", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves'}
  for stop_word in stop_words:
    if stop_word in index:
      del index[stop_word]
  return index

# Apply stemming to the index
def apply_stemming(index):
  stemmer = PorterStemmer()
  stemmed_index = {}
  for word, count in index.items():
    stemmed_word = stemmer.stem(word)
    if stemmed_word in stemmed_index:
      stemmed_index[stemmed_word] += count
    else:
      stemmed_index[stemmed_word] = count
  return stemmed_index


def remove_infrequent_words(index, threshold):
  for word, count in list(index.items()):
    if count < threshold:
      del index[word]
  return index

# Run the index creation of selected url
def create_index(url):    # rename to index creaation
  soup = fetch_page(url)
  if soup is None:
     return None
  index = index_words(soup)
  index = remove_stop_words(index)
  index = apply_stemming(index)
  index = remove_infrequent_words(index, 2)
  return index

# %%
def get_sub_urls(start_url):
    """
    Fetches all sub-URLs from a given URL site.

    Args:
        url (str): The base URL to crawl.

    Returns:
        list: A list of sub-URLs in the site.
    """
    url_query = [start_url]
    sub_urls = [start_url]
    while url_query != []:
      # get first url
      url = url_query[0]
      url_query.remove(url)

      # run scrape on the current page
      response = requests.get(url)      #ToDo: need to run in depth
      response.raise_for_status()  # Raise an exception for bad responses

      soup = BeautifulSoup(response.content, 'html.parser')

      for link in soup.find_all('a', href=True):
          href = link['href']
          absolute_url = urljoin(url, href)  # Make URL absolute

          if absolute_url.startswith(url) and absolute_url != url and absolute_url not in sub_urls:
              sub_urls.append(absolute_url)

              if absolute_url not in url_query:
                  url_query.append(absolute_url)

    return sub_urls

# %%
# This section will run on every sub site and create the index

# get the sub url list
site_urls = get_sub_urls(url)

site_index = {}
for sub_url in site_urls:
  idx = create_index(sub_url)

  # marge idx to site_index
  for word in idx:
    if word in site_index:
      site_index[word].append((sub_url, idx[word]))
    else:
      site_index[word] = [(sub_url, idx[word])]

# Save the index to FireBase

# Initialize Firebase connection
FBconn = firebase.FirebaseApplication(DBLink, None)

# Upload the site_index to Firebase
FBconn.put('/', 'site_index', site_index)
# Out:
# {'abl': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'abli': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'acceler': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'access': [['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'accord': [['https://mqtt.org/legal', 4]],
#  'acl': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'acronym': [['https://mqtt.org/faq/', 1]],
#  'across': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/faq/', 2],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'act': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'action': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'actionscript': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'activ': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/legal', 4],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'activemq': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'actor': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'actuat': [['https://mqtt.org/mqtt-specification/', 1]],
#  'ad': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'ada': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'adapt': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'add': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'addit': [['https://mqtt.org/software/', 7],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 7]],
#  'address': [['https://mqtt.org/legal', 2]],
#  'adher': [['https://mqtt.org/legal', 4]],
#  'adopt': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'advanc': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'agreement': [['https://mqtt.org/legal', 1]],
#  'aim': [['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'air': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'aka': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'akin': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'akiro': [['https://mqtt.org/software/', 7],
#   ['https://mqtt.org/software/#shell-script', 7]],
#  'alert': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'alik': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'allow': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'alon': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'alphawork': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'also': [['https://mqtt.org/software/', 9],
#   ['https://mqtt.org/faq/', 4],
#   ['https://mqtt.org/software/#shell-script', 9]],
#  'amlen': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'among': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'amount': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'amqp': [['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'analysi': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'analyt': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/legal', 5],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'analyz': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'andi': [['https://mqtt.org/faq/', 1]],
#  'android': [['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'anonym': [['https://mqtt.org/legal', 2]],
#  'ant': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'anyev': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'apach': [['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'apache2': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'api': [['https://mqtt.org/software/', 12],
#   ['https://mqtt.org/software/#shell-script', 12]],
#  'app': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'applianc': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'applic': [['https://mqtt.org/software/', 19],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/faq/', 2],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 19]],
#  'appropri': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'aqara': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'architectur': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'arcom': [['https://mqtt.org/faq/', 1]],
#  'arduino': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'area': [['https://mqtt.org/legal', 1]],
#  'arlen': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'around': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'art': [['https://mqtt.org/legal', 2]],
#  'artemi': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'articl': [['https://mqtt.org/getting-started/', 1]],
#  'as3mqtt': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'ascoltatori': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'ash': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'asio': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'ask': [['https://mqtt.org/faq/', 1]],
#  'asset': [['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'assur': [['https://mqtt.org/faq/', 1]],
#  'async': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'async_mqtt': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'asynchron': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'asyncio': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'attempt': [['https://mqtt.org/faq/', 1]],
#  'attract': [['https://mqtt.org/legal', 1]],
#  'attribut': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'auth': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'authent': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'autom': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'automat': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'automot': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'avail': [['https://mqtt.org/mqtt-specification/', 4],
#   ['https://mqtt.org/software/', 17],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 17]],
#  'avoid': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'back': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'backend': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'backpressur': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'backward': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'baidu': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'ballerina': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'bandwidth': [['https://mqtt.org/', 2], ['https://mqtt.org/faq/', 3]],
#  'barracuda': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'base': [['https://mqtt.org/software/', 24],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 24]],
#  'bash': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'basi': [['https://mqtt.org/legal', 1]],
#  'basic': [['https://mqtt.org/getting-started/', 2],
#   ['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'batteri': [['https://mqtt.org/faq/', 1]],
#  'battl': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'beforehand': [['https://mqtt.org/legal', 1]],
#  'began': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'beginn': [['https://mqtt.org/getting-started/', 2]],
#  'behalf': [['https://mqtt.org/legal', 1]],
#  'behavior': [['https://mqtt.org/legal', 1]],
#  'bench': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'benchmark': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'best': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'bevywis': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'beyond': [['https://mqtt.org/mqtt-specification/', 1]],
#  'bi': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'bidirect': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'bifromq': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'binari': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'bind': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'bish': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'blaze': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'block': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'blog': [['https://mqtt.org/getting-started/', 2],
#   ['https://mqtt.org/mqtt-specification/', 1]],
#  'bmw': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'board': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'boost': [['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'bosh': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'boundari': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'bridg': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'broadcast': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'broker': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 76],
#   ['https://mqtt.org/faq/', 4],
#   ['https://mqtt.org/software/#shell-script', 76]],
#  'browser': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/legal', 5],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'bu': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'buffer': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'build': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'built': [['https://mqtt.org/software/', 7],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 7]],
#  'bundl': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'bursti': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'busi': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'busybox': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'button': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'c': [['https://mqtt.org/software/', 29],
#   ['https://mqtt.org/software/#shell-script', 29]],
#  'cach': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'call': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'callback': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'capabl': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'capac': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'car': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'case': [['https://mqtt.org/', 3],
#   ['https://mqtt.org/getting-started/', 2],
#   ['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/use-cases/', 7],
#   ['https://mqtt.org/faq/', 3],
#   ['https://mqtt.org/use-cases#automotive', 7],
#   ['https://mqtt.org/use-cases#logistics', 7],
#   ['https://mqtt.org/use-cases#manufacturing', 7],
#   ['https://mqtt.org/use-cases#smarthome', 7],
#   ['https://mqtt.org/use-cases#consumer-products', 7],
#   ['https://mqtt.org/use-cases#transportation', 7],
#   ['https://mqtt.org/legal', 4],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'caso': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'cassandana': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'celikl': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'cell': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'cellular': [['https://mqtt.org/', 1]],
#  'certifi': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/legal', 4],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'chang': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'channel': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'charg': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'chat': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'check': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'choral': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'cirru': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'clark': [['https://mqtt.org/faq/', 1]],
#  'class': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'classic': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'cleanup': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'cli': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'click': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'client': [['https://mqtt.org/', 3],
#   ['https://mqtt.org/software/', 86],
#   ['https://mqtt.org/software/#shell-script', 86]],
#  'clojur': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'cloud': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/software/', 29],
#   ['https://mqtt.org/software/#shell-script', 29]],
#  'cluster': [['https://mqtt.org/software/', 11],
#   ['https://mqtt.org/software/#shell-script', 11]],
#  'coap': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'cocoamqtt': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'code': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 8],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 8]],
#  'codec': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'collect': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'com': [['https://mqtt.org/getting-started/', 2],
#   ['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'come': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'command': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'commerc': [['https://mqtt.org/legal', 2]],
#  'commerci': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'commiss': [['https://mqtt.org/legal', 2]],
#  'commit': [['https://mqtt.org/legal', 4]],
#  'committe': [['https://mqtt.org/mqtt-specification/', 2]],
#  'commod': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'commonli': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'commun': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 13],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 13]],
#  'compani': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'compat': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'compil': [['https://mqtt.org/legal', 1]],
#  'complet': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'complex': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'compli': [['https://mqtt.org/legal', 4]],
#  'complianc': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'compon': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'comput': [['https://mqtt.org/legal', 1]],
#  'concentr': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'concept': [['https://mqtt.org/getting-started/', 2]],
#  'concurr': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'configur': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'connect': [['https://mqtt.org/', 3],
#   ['https://mqtt.org/software/', 20],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/faq/', 3],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 20]],
#  'connector': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'consert': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'consid': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'consist': [['https://mqtt.org/legal', 1]],
#  'constrain': [['https://mqtt.org/faq/', 1]],
#  'consum': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'contain': [['https://mqtt.org/legal', 1]],
#  'content': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'context': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'continu': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'contribut': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'control': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'convers': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'convert': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'cooki': [['https://mqtt.org/legal', 3]],
#  'cool': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'cordova': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'core': [['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'coreflux': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'coroutin': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'correctli': [['https://mqtt.org/legal', 1]],
#  'cost': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'count': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'cours': [['https://mqtt.org/getting-started/', 1]],
#  'cpan': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'creat': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'credenti': [['https://mqtt.org/legal', 1]],
#  'critic': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'crm': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'cross': [['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'crystalmq': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'curl': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'custom': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'customiz': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'cut': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'cyclic': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'daemon': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'dart': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'dash': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'dashboard': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'data': [['https://mqtt.org/software/', 15],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 15]],
#  'databas': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'datafram': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'day': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'db': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'dbu': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'de': [['https://mqtt.org/legal', 2]],
#  'deactiv': [['https://mqtt.org/legal', 1]],
#  'dead': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'debug': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'decis': [['https://mqtt.org/legal', 2]],
#  'declar': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'decod': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'defin': [['https://mqtt.org/', 1]],
#  'degre': [['https://mqtt.org/faq/', 1]],
#  'deliv': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'deliveri': [['https://mqtt.org/', 2], ['https://mqtt.org/faq/', 1]],
#  'delphi': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'depart': [['https://mqtt.org/legal', 2]],
#  'depend': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'deploy': [['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'deprec': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'design': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 8],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/faq/', 2],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 8]],
#  'desktop': [['https://mqtt.org/software/', 10],
#   ['https://mqtt.org/software/#shell-script', 10]],
#  'detail': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'dev': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'develop': [['https://mqtt.org/software/', 10],
#   ['https://mqtt.org/software/#shell-script', 10]],
#  'devic': [['https://mqtt.org/', 5],
#   ['https://mqtt.org/mqtt-specification/', 1],
#   ['https://mqtt.org/software/', 21],
#   ['https://mqtt.org/faq/', 3],
#   ['https://mqtt.org/software/#shell-script', 21]],
#  'diagnost': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'dialogu': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'differ': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'direct': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'directori': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'disabl': [['https://mqtt.org/legal', 1]],
#  'discuss': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'dispatch': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'display': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'dissector': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'distribut': [['https://mqtt.org/software/', 7],
#   ['https://mqtt.org/software/#shell-script', 7]],
#  'dlm': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'dlpage': [['https://mqtt.org/legal', 1]],
#  'document': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'domain': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'dongl': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'dotnet': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'download': [['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'dozen': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'dr': [['https://mqtt.org/faq/', 1]],
#  'driver': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'dynam': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'easi': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'easili': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'eclips': [['https://mqtt.org/software/', 19],
#   ['https://mqtt.org/faq/', 3],
#   ['https://mqtt.org/software/#shell-script', 19]],
#  'econom': [['https://mqtt.org/legal', 1]],
#  'edg': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'edit': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'effici': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'efon': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'either': [['https://mqtt.org/mqtt-specification/', 2]],
#  'ejabberd': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'elecsi': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'electr': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'elixir': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'em': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'embed': [['https://mqtt.org/mqtt-specification/', 1],
#   ['https://mqtt.org/software/', 12],
#   ['https://mqtt.org/software/#shell-script', 12]],
#  'embedd': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'emitt': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'emq': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'emqtech': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'emqtt5': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'emqttc': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'emqx': [['https://mqtt.org/software/', 7],
#   ['https://mqtt.org/software/#shell-script', 7]],
#  'en': [['https://mqtt.org/legal', 3]],
#  'enabl': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'encod': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'encrypt': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/faq/', 2],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'energi': [['https://mqtt.org/use-cases/', 3],
#   ['https://mqtt.org/use-cases#automotive', 3],
#   ['https://mqtt.org/use-cases#logistics', 3],
#   ['https://mqtt.org/use-cases#manufacturing', 3],
#   ['https://mqtt.org/use-cases#smarthome', 3],
#   ['https://mqtt.org/use-cases#consumer-products', 3],
#   ['https://mqtt.org/use-cases#transportation', 3]],
#  'engin': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'enhanc': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'ensur': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'enterpris': [['https://mqtt.org/software/', 10],
#   ['https://mqtt.org/software/#shell-script', 10]],
#  'entir': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'environ': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'ep': [['https://mqtt.org/mqtt-specification/', 1]],
#  'erl': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'erlang': [['https://mqtt.org/software/', 7],
#   ['https://mqtt.org/software/#shell-script', 7]],
#  'erlmqtt': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'erp': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'esb': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'esp8266': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'espduino': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'essenti': [['https://mqtt.org/getting-started/', 1]],
#  'etc': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'eu': [['https://mqtt.org/legal', 6]],
#  'european': [['https://mqtt.org/legal', 4]],
#  'eurotech': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'evalu': [['https://mqtt.org/legal', 1]],
#  'event': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'everi': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'everywher': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'exactli': [['https://mqtt.org/', 1]],
#  'exampl': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'except': [['https://mqtt.org/legal', 1]],
#  'exmqttc': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'experi': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'experiment': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'explor': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'expos': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'extend': [['https://mqtt.org/mqtt-specification/', 1],
#   ['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'extens': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'extern': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/legal', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'extra': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'extrem': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'f': [['https://mqtt.org/legal', 2]],
#  'facilit': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'factori': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'failov': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'failur': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'faq': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/getting-started/', 2],
#   ['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/faq/', 4],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'fashion': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'fast': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'faster': [['https://mqtt.org/legal', 1]],
#  'fault': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'featur': [['https://mqtt.org/software/', 13],
#   ['https://mqtt.org/software/#shell-script', 13]],
#  'feder': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'feel': [['https://mqtt.org/mqtt-specification/', 1]],
#  'field': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'file': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'find': [['https://mqtt.org/faq/', 1]],
#  'first': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'flashmq': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'flavour': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'flespi': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'flexibl': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'fli': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'flow': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'flowfus': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'flukso': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'fluksomet': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'flux': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'focu': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'follow': [['https://mqtt.org/legal', 2]],
#  'font': [['https://mqtt.org/legal', 7]],
#  'footprint': [['https://mqtt.org/', 1]],
#  'fork': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'form': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'format': [['https://mqtt.org/mqtt-specification/', 1],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'formerli': [['https://mqtt.org/mqtt-specification/', 1],
#   ['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'forth': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'forward': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'framework': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/legal', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'franc': [['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
# ...
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1]],
#  'sampl': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'san': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'save': [['https://mqtt.org/mqtt-specification/', 4]],
#  'scada': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'scalabl': [['https://mqtt.org/software/', 11],
#   ['https://mqtt.org/software/#shell-script', 11]],
#  'scalag': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'scale': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/software/', 8],
#   ['https://mqtt.org/software/#shell-script', 8]],
#  'scenario': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'scheme': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'script': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'sdk': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'seamless': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'second': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'secur': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 13],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/faq/', 2],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 13]],
#  'see': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'seek': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'select': [['https://mqtt.org/legal', 1]],
#  'self': [['https://mqtt.org/legal', 4]],
#  'send': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'sensin': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'sensor': [['https://mqtt.org/mqtt-specification/', 3],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'sent': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/legal', 3],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'sentienz': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'separ': [['https://mqtt.org/legal', 1]],
#  'seri': [['https://mqtt.org/getting-started/', 1]],
#  'server': [['https://mqtt.org/software/', 27],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/legal', 3],
#   ['https://mqtt.org/software/#shell-script', 27]],
#  'serverless': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'servic': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 12],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/legal', 6],
#   ['https://mqtt.org/software/#shell-script', 12]],
#  'session': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'set': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'sever': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'share': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'sharkmqtt': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'shell': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'shield': [['https://mqtt.org/legal', 4]],
#  'ship': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'shorten': [['https://mqtt.org/legal', 2]],
#  'shot': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'side': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'sign': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'signific': [['https://mqtt.org/faq/', 1]],
#  'simp': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'simpl': [['https://mqtt.org/software/', 11],
#   ['https://mqtt.org/faq/', 2],
#   ['https://mqtt.org/software/#shell-script', 11]],
#  'simplifi': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'simul': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'sinc': [['https://mqtt.org/faq/', 1]],
#  'singl': [['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'site': [['https://mqtt.org/legal', 1]],
#  'size': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'sla': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'small': [['https://mqtt.org/', 4],
#   ['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'smalltalk': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'smart': [['https://mqtt.org/', 1],
#   ['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/use-cases/', 3],
#   ['https://mqtt.org/use-cases#automotive', 3],
#   ['https://mqtt.org/use-cases#logistics', 3],
#   ['https://mqtt.org/use-cases#manufacturing', 3],
#   ['https://mqtt.org/use-cases#smarthome', 3],
#   ['https://mqtt.org/use-cases#consumer-products', 3],
#   ['https://mqtt.org/use-cases#transportation', 3],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'sn': [['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'socket': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'softwar': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/getting-started/', 2],
#   ['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 8],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/faq/', 3],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 8]],
#  'solac': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'solut': [['https://mqtt.org/mqtt-specification/', 1],
#   ['https://mqtt.org/software/', 8],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/software/#shell-script', 8]],
#  'someth': [['https://mqtt.org/faq/', 1]],
#  'sourc': [['https://mqtt.org/software/', 31],
#   ['https://mqtt.org/software/#shell-script', 31]],
#  'sparkplugb': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'specif': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/getting-started/', 2],
#   ['https://mqtt.org/mqtt-specification/', 11],
#   ['https://mqtt.org/software/', 8],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/faq/', 4],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 8]],
#  'specifi': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'spectacular': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'spi': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'squeak': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'sse': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'sskaje': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'ssl': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/faq/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'stackoverflow': [['https://mqtt.org/faq/', 1]],
#  'stand': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'standalon': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'standard': [['https://mqtt.org/', 3],
#   ['https://mqtt.org/mqtt-specification/', 3],
#   ['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/faq/', 4],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'standout': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'stanford': [['https://mqtt.org/faq/', 1]],
#  'start': [['https://mqtt.org/', 3],
#   ['https://mqtt.org/getting-started/', 6],
#   ['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/faq/', 2],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'stat': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'state': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/legal', 2],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'statist': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'statu': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'steroid': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'steve': [['https://mqtt.org/getting-started/', 2]],
#  'stomp': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'storag': [['https://mqtt.org/software/', 4],
#   ['https://mqtt.org/software/#shell-script', 4]],
#  'store': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/legal', 1],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'stream': [['https://mqtt.org/software/', 5],
#   ['https://mqtt.org/software/#shell-script', 5]],
#  'stridermqtt': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'strive': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'strongli': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'studio': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'sub': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'submit': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/use-cases/', 1],
#   ['https://mqtt.org/use-cases#automotive', 1],
#   ['https://mqtt.org/use-cases#logistics', 1],
#   ['https://mqtt.org/use-cases#manufacturing', 1],
#   ['https://mqtt.org/use-cases#smarthome', 1],
#   ['https://mqtt.org/use-cases#consumer-products', 1],
#   ['https://mqtt.org/use-cases#transportation', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'subscrib': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/mqtt-specification/', 1],
#   ['https://mqtt.org/software/', 12],
#   ['https://mqtt.org/faq/', 2],
#   ['https://mqtt.org/software/#shell-script', 12]],
#  'subscript': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'success': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'suit': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'suitabl': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'support': [['https://mqtt.org/', 2],
#   ['https://mqtt.org/software/', 61],
#   ['https://mqtt.org/faq/', 1],
#   ['https://mqtt.org/software/#shell-script', 61]],
#  'supportpac': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'svg': [['https://mqtt.org/mqtt-specification/', 1],
#   ['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'swarm': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'swi': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'swift': [['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'swiftmq': [['https://mqtt.org/software/', 6],
#   ['https://mqtt.org/software/#shell-script', 6]],
#  'swing': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'system': [['https://mqtt.org/software/', 17],
#   ['https://mqtt.org/use-cases/', 2],
#   ['https://mqtt.org/use-cases#automotive', 2],
#   ['https://mqtt.org/use-cases#logistics', 2],
#   ['https://mqtt.org/use-cases#manufacturing', 2],
#   ['https://mqtt.org/use-cases#smarthome', 2],
#   ['https://mqtt.org/use-cases#consumer-products', 2],
#   ['https://mqtt.org/use-cases#transportation', 2],
#   ['https://mqtt.org/software/#shell-script', 17]],
#  'tabl': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'tailor': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'take': [['https://mqtt.org/legal', 1]],
#  'talk': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'target': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'task': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'tasmota': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'tasmotamqtt': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'tc': [['https://mqtt.org/mqtt-specification/', 1]],
#  'tcl': [['https://mqtt.org/software/', 2],
#   ['https://mqtt.org/software/#shell-script', 2]],
#  'tcp': [['https://mqtt.org/mqtt-specification/', 2],
#   ['https://mqtt.org/software/', 3],
#   ['https://mqtt.org/faq/', 2],
#   ['https://mqtt.org/software/#shell-script', 3]],
#  'tdi': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  'team': [['https://mqtt.org/software/', 1],
#   ['https://mqtt.org/software/#shell-script', 1]],
#  ...}

# %% [markdown]
# 1173 start
# 1148 without digits
# 562 remove words that appeare less then 2
#
# The index now with 562 words

# %% [markdown]
# # Search window

# %%
# prompt: I want to use gradio and create a search form that let you search words in the index above, and show the links that the word appear ordered by the counter add function to read the index from the firebase db, and if the user enter the word with typo, try to fix the word and search

import gradio as gr
from difflib import get_close_matches

def read_index_from_firebase():
    """Reads the site index from the Firebase database."""
    FBconn = firebase.FirebaseApplication(DBLink, None)
    site_index = FBconn.get('/', 'site_index')
    return site_index if site_index else {}

def search_words(query):
    """
    Searches for words in the index and returns the URLs ordered by count.
    Attempts to fix typos and suggest unstemmed words from a dictionary.
    Formats output as HTML with clickable links.
    """
    site_index = read_index_from_firebase()
    if not site_index:
        # Return a simple error message formatted as HTML
        return "<p>Error: Could not read index from Firebase.</p>"

    stemmer = PorterStemmer()
    query_words = re.findall(r'\w+', query.lower())
    output_html = "" # Use an HTML string for output

    for word in query_words:
        stemmed_word = stemmer.stem(word)

        if stemmed_word in site_index:
            output_html += f"<h2>Results for '{word}':</h2>"
            # Sort URLs by count in descending order
            sorted_urls = sorted(site_index[stemmed_word], key=lambda item: item[1], reverse=True)
            output_html += "<ul>" # Use an unordered list for the links
            for url, count in sorted_urls:
                # Format the URL as an HTML link
                output_html += f"<li><a href='{url}' target='_blank'>{url}</a> (Count: {count})</li>"
            output_html += "</ul>"
            output_html += "<br>" # Add a break after each word's results
        else:
            # Try to fix typo (search for the steammed word)
            # ToDo?: try to create the currect word
            all_words = list(site_index.keys())
            matches = get_close_matches(stemmed_word, all_words, n=1, cutoff=0.8)
            if matches:
                corrected_stemmed_word = matches[0]

                output_html += f"<p>Did you mean '{corrected_stemmed_word}'?</p>"
                output_html += f"<h2>Results for '{corrected_stemmed_word}':</h2>"

                # Sort URLs by count in descending order
                sorted_urls = sorted(site_index[corrected_stemmed_word], key=lambda item: item[1], reverse=True)
                output_html += "<ul>" # Use an unordered list for the links
                for url, count in sorted_urls:
                     # Format the URL as an HTML link
                     output_html += f"<li><a href='{url}' target='_blank'>{url}</a> (Count: {count})</li>"
                output_html += "</ul>"
                output_html += "<br>"
            else:
                output_html += f"<p>No results found for '{word}' and no close matches found.</p><br>"

    if not output_html: # Check if any output was generated
        return "<p>No results found for your query.</p>"

    return output_html

# Modify the Gradio interface
iface = gr.Interface(
    fn=search_words,
    inputs=gr.Textbox(label="Enter words to search"),
    outputs=gr.HTML(label="Search Results"), # Change output to gr.HTML
    title="Website Search Engine",
    description="Enter words to search the indexed website. Results are ordered by word count on each page.",
    flagging_mode="never"
)

iface.launch(debug=False)
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://0c677e7d4cc876db49.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0c677e7d4cc876db49.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
