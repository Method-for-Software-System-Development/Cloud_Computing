# %% [markdown]
# <a href="https://colab.research.google.com/github/Method-for-Software-System-Development/Cloud_Computing/blob/develop/logic/FAULT_RULES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
FAULT_RULES = {
    "temperature_indoor": [
        {
            "min": 30,
            "max": 35,
            "severity": "Medium",
            "sensor": "Indoor Temperature",
            "status": "Active",
            "title": "Indoor Temperature between 30°C–35°C",
            "repaired_by": "",
            "actions": [
                "Monitor the room temperature",
                "Check if the cooling system is functioning"
            ]
        },
        {
            "min": 35,
            "max": None,
            "severity": "High",
            "sensor": "Indoor Temperature",
            "status": "Active",
            "title": "Indoor Temperature above 35°C",
            "repaired_by": "",
            "actions": [
                "Turn on the cooling system",
                "Inspect the indoor temperature sensor",
                "Check if the cooling system is functioning"
            ]
        }
    ],
    "humidity_indoor": [
        {
            "min": None,
            "max": 30,
            "severity": "Medium",
            "sensor": "Indoor Humidity",
            "status": "Active",
            "title": "Indoor Humidity below 30%",
            "repaired_by": "",
            "actions": [
                "Activate the humidifier",
                "Check HVAC settings"
            ]
        },
        {
            "min": 70,
            "max": 90,
            "severity": "Medium",
            "sensor": "Indoor Humidity",
            "status": "Active",
            "title": "Indoor Humidity between 70%–90%",
            "repaired_by": "",
            "actions": [
                "Turn on the dehumidifier"
            ]
        },
        {
            "min": 90,
            "max": None,
            "severity": "High",
            "sensor": "Indoor Humidity",
            "status": "Active",
            "title": "Indoor Humidity above 90%",
            "repaired_by": "",
            "actions": [
                "check if the dehumidifier is on",
                "Check for leaks or water intrusion"
            ]
        }
    ],
    "pressure_indoor": [
        {
            "min": None,
            "max": 920,
            "severity": "High",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure below 920 hPa",
            "repaired_by": "",
            "actions": [
                "Check sensor calibration",
                "Ensure no air leakage in the system"
            ]
        },
        {
            "min": 920,
            "max": 940,
            "severity": "Medium",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure between 920–940 hPa",
            "repaired_by": "",
            "actions": [
                "Inspect for anomalies",
                "Compare with external pressure readings"
            ]
        },
        {
            "min": 940,
            "max": 960,
            "severity": "Low",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure between 940–960 hPa",
            "repaired_by": "",
            "actions": [
                "Log the event",
                "Monitor for further pressure drops"
            ]
        },
        {
            "min": 1040,
            "max": 1060,
            "severity": "Low",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure between 1040–1060 hPa",
            "repaired_by": "",
            "actions": [
                "No immediate action required",
                "Observe for long-term trends"
            ]
        },
        {
            "min": 1060,
            "max": 1080,
            "severity": "Medium",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure between 1060–1080 hPa",
            "repaired_by": "",
            "actions": [
                "Check for sensor drift",
                "Validate with secondary sensor"
            ]
        },
        {
            "min": 1080,
            "max": None,
            "severity": "High",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure above 1080 hPa",
            "repaired_by": "",
            "actions": [
                "Recalibrate or replace the sensor",
                "Notify technical support"
            ]
        }
    ],
    "distance_indoor": [
        {
            "min": None,
            "max": 10,
            "severity": "High",
            "sensor": "Indoor Distance",
            "status": "Active",
            "title": "Indoor Distance below 10 cm",
            "repaired_by": "",
            "actions": [
                "Check the proximity sensor",
                "Ensure there are no obstacles",
                "Investigate possible blockages"
            ]
        }
    ],
    "temperature_outdoor": [
        {
            "min": 40,
            "max": 50,
            "severity": "Medium",
            "sensor": "Outdoor Temperature",
            "status": "Active",
            "title": "Outdoor Temperature between 40°C–50°C",
            "repaired_by": "",
            "actions": [
                "Monitor for overheating",
                "Limit direct sunlight exposure"
            ]
        },
        {
            "min": 50,
            "max": None,
            "severity": "High",
            "sensor": "Outdoor Temperature",
            "status": "Active",
            "title": "Outdoor Temperature above 50°C",
            "repaired_by": "",
            "actions": [
                "Shut down exposed systems",
                "Activate high-temperature protocols"
            ]
        },
        {
            "min": None,
            "max": 0,
            "severity": "Low",
            "sensor": "Outdoor Temperature",
            "status": "Active",
            "title": "Outdoor Temperature below 0°C",
            "repaired_by": "",
            "actions": [
                "Check heating mechanisms",
                "Protect equipment from freezing"
            ]
        }
    ],
    "humidity_outdoor": [
        {
            "min": 80,
            "max": None,
            "severity": "Low",
            "sensor": "Outdoor Humidity",
            "status": "Active",
            "title": "Outdoor Humidity above 80%",
            "repaired_by": "",
            "actions": [
                "Ensure weatherproofing",
                "Inspect sensors for condensation"
            ]
        }
    ]
}
