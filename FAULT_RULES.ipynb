# %% [markdown]
# <a href="https://colab.research.google.com/github/Method-for-Software-System-Development/Cloud_Computing/blob/develop/FAULT_RULES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
FAULT_RULES = {
    "temperature_indoor": [
        {
            "threshold": 35,
            "operator": ">",
            "severity": "High",
            "sensor": "Indoor Temperature",
            "status": "Active",
            "message": "Temperature exceeded 35°C",
            "actions": [
                "Turn on the cooling system",
                "Open windows if possible",
                "Inspect the indoor temperature sensor"
            ]
        },
        {
            "threshold": 30,
            "operator": ">",
            "severity": "Medium",
            "sensor": "Indoor Temperature",
            "status": "Active",
            "message": "Temperature exceeded 30°C",
            "actions": [
                "Monitor the room temperature",
                "Check if the cooling system is functioning"
            ]
        }
    ],
    "humidity_indoor": [
        {
            "threshold": 30,
            "operator": "<",
            "severity": "Medium",
            "sensor": "Indoor Humidity",
            "status": "Active",
            "message": "Humidity dropped below 30%",
            "actions": [
                "Activate the humidifier",
                "Check HVAC settings"
            ]
        },
        {
            "threshold": 70,
            "operator": ">",
            "severity": "Medium",
            "sensor": "Indoor Humidity",
            "status": "Active",
            "message": "Humidity exceeded 70%",
            "actions": [
                "Turn on the dehumidifier",
                "Check for leaks or water intrusion"
            ]
        }
    ],
    "pressure_indoor": [
        {
            "threshold": 920,
            "operator": "<",
            "severity": "High",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "message": "Very low pressure – likely a sensor fault",
            "actions": [
                "Check sensor calibration",
                "Ensure no air leakage in the system"
            ]
        },
        {
            "threshold": 940,
            "operator": "<",
            "severity": "Medium",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "message": "Significant low pressure – possible sensor issue",
            "actions": [
                "Inspect for anomalies",
                "Compare with external pressure readings"
            ]
        },
        {
            "threshold": 960,
            "operator": "<",
            "severity": "Low",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "message": "Slightly low pressure – weather fluctuation or minor issue",
            "actions": [
                "Log the event",
                "Monitor for further pressure drops"
            ]
        },
        {
            "threshold": 1040,
            "operator": ">",
            "severity": "Low",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "message": "Slightly high pressure – possibly stable weather",
            "actions": [
                "No immediate action required",
                "Observe for long-term trends"
            ]
        },
        {
            "threshold": 1060,
            "operator": ">",
            "severity": "Medium",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "message": "Unusually high pressure – possible abnormal conditions",
            "actions": [
                "Check for sensor drift",
                "Validate with secondary sensor"
            ]
        },
        {
            "threshold": 1080,
            "operator": ">",
            "severity": "High",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "message": "Unrealistic high pressure – likely sensor malfunction",
            "actions": [
                "Recalibrate or replace the sensor",
                "Notify technical support"
            ]
        }
    ],
    "distance_indoor": [
        {
            "threshold": 10,
            "operator": "<",
            "severity": "High",
            "sensor": "Indoor Distance",
            "status": "Active",
            "message": "Object detected very close (< 10 cm)",
            "actions": [
                "Check the proximity sensor",
                "Ensure there are no obstacles",
                "Investigate possible blockages"
            ]
        }
    ],
    "temperature_outdoor": [
        {
            "threshold": 50,
            "operator": ">",
            "severity": "High",
            "sensor": "Outdoor Temperature",
            "status": "Active",
            "message": "Outdoor temperature exceeded 50°C",
            "actions": [
                "Shut down exposed systems",
                "Activate high-temperature protocols"
            ]
        },
        {
            "threshold": 40,
            "operator": ">",
            "severity": "Medium",
            "sensor": "Outdoor Temperature",
            "status": "Active",
            "message": "Outdoor temperature exceeded 40°C",
            "actions": [
                "Monitor for overheating",
                "Limit direct sunlight exposure"
            ]
        },
        {
            "threshold": 0,
            "operator": "<",
            "severity": "Low",
            "sensor": "Outdoor Temperature",
            "status": "Active",
            "message": "Outdoor temperature dropped below 0°C",
            "actions": [
                "Check heating mechanisms",
                "Protect equipment from freezing"
            ]
        }
    ],
    "humidity_outdoor": [
        {
            "threshold": 80,
            "operator": ">",
            "severity": "Low",
            "sensor": "Outdoor Humidity",
            "status": "Active",
            "message": "Outdoor humidity exceeded 80%",
            "actions": [
                "Ensure weatherproofing",
                "Inspect sensors for condensation"
            ]
        }
    ]
}
