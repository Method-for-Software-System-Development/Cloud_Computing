# %% [markdown]
# <a href="https://colab.research.google.com/github/Method-for-Software-System-Development/Cloud_Computing/blob/develop/FAULT_RULES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
FAULT_RULES = {
    "temperature_indoor": [
        {
            "threshold": 35,
            "operator": ">",
            "severity": "High",
            "sensor": "Indoor Temperature",
            "status": "Active",
            "title": "Indoor Temperature above 35°C",
            "repaired_by": "",
            "actions": [
                "Turn on the cooling system",
                "Inspect the indoor temperature sensor",
                "Check if the cooling system is functioning"
            ]
        },
        {
            "threshold": 30,
            "operator": ">",
            "severity": "Medium",
            "sensor": "Indoor Temperature",
            "status": "Active",
            "title": "Indoor Temperature above 30°C",
            "repaired_by": "",
            "actions": [
                "Monitor the room temperature",
                "Check if the cooling system is functioning"
            ]
        }
    ],
    "humidity_indoor": [
        {
            "threshold": 30,
            "operator": "<",
            "severity": "Medium",
            "sensor": "Indoor Humidity",
            "status": "Active",
            "title": "Indoor Humidity below 30%",
            "repaired_by": "",
            "actions": [
                "Activate the humidifier",
                "Check HVAC settings"
            ]
        },
        {
            "threshold": 70,
            "operator": ">",
            "severity": "Medium",
            "sensor": "Indoor Humidity",
            "status": "Active",
            "title": "Indoor Humidity above 70%",
            "repaired_by": "",
            "actions": [
                "Turn on the dehumidifier"
            ]
        },
        {
            "threshold": 90,
            "operator": ">",
            "severity": "High",
            "sensor": "Indoor Humidity",
            "status": "Active",
            "title": "Indoor Humidity above 90%",
            "repaired_by": "",
            "actions": [
                "check if the dehumidifier is on",
                "Check for leaks or water intrusion"
            ]
        }
    ],
    "pressure_indoor": [
        {
            "threshold": 920,
            "operator": "<",
            "severity": "High",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure below 920 hPa",
            "repaired_by": "",
            "actions": [
                "Check sensor calibration",
                "Ensure no air leakage in the system"
            ]
        },
        {
            "threshold": 940,
            "operator": "<",
            "severity": "Medium",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure below 940 hPa",
            "repaired_by": "",
            "actions": [
                "Inspect for anomalies",
                "Compare with external pressure readings"
            ]
        },
        {
            "threshold": 960,
            "operator": "<",
            "severity": "Low",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure below 960 hPa",
            "repaired_by": "",
            "actions": [
                "Log the event",
                "Monitor for further pressure drops"
            ]
        },
        {
            "threshold": 1040,
            "operator": ">",
            "severity": "Low",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure above 1040 hPa",
            "repaired_by": "",
            "actions": [
                "No immediate action required",
                "Observe for long-term trends"
            ]
        },
        {
            "threshold": 1060,
            "operator": ">",
            "severity": "Medium",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure above 1060 hPa",
            "repaired_by": "",
            "actions": [
                "Check for sensor drift",
                "Validate with secondary sensor"
            ]
        },
        {
            "threshold": 1080,
            "operator": ">",
            "severity": "High",
            "sensor": "Indoor Pressure",
            "status": "Active",
            "title": "Indoor Pressure above 1080 hPa",
            "repaired_by": "",
            "actions": [
                "Recalibrate or replace the sensor",
                "Notify technical support"
            ]
        }
    ],
    "distance_indoor": [
        {
            "threshold": 10,
            "operator": "<",
            "severity": "High",
            "sensor": "Indoor Distance",
            "status": "Active",
            "title": "Indoor Distance below 10 cm",
            "repaired_by": "",
            "actions": [
                "Check the proximity sensor",
                "Ensure there are no obstacles",
                "Investigate possible blockages"
            ]
        }
    ],
    "temperature_outdoor": [
        {
            "threshold": 50,
            "operator": ">",
            "severity": "High",
            "sensor": "Outdoor Temperature",
            "status": "Active",
            "title": "Outdoor Temperature above 50°C",
            "repaired_by": "",
            "actions": [
                "Shut down exposed systems",
                "Activate high-temperature protocols"
            ]
        },
        {
            "threshold": 40,
            "operator": ">",
            "severity": "Medium",
            "sensor": "Outdoor Temperature",
            "status": "Active",
            "title": "Outdoor Temperature above 40°C",
            "repaired_by": "",
            "actions": [
                "Monitor for overheating",
                "Limit direct sunlight exposure"
            ]
        },
        {
            "threshold": 0,
            "operator": "<",
            "severity": "Low",
            "sensor": "Outdoor Temperature",
            "status": "Active",
            "title": "Outdoor Temperature below 0°C",
            "repaired_by": "",
            "actions": [
                "Check heating mechanisms",
                "Protect equipment from freezing"
            ]
        }
    ],
    "humidity_outdoor": [
        {
            "threshold": 80,
            "operator": ">",
            "severity": "Low",
            "sensor": "Outdoor Humidity",
            "status": "Active",
            "title": "Outdoor Humidity above 80%",
            "repaired_by": "",
            "actions": [
                "Ensure weatherproofing",
                "Inspect sensors for condensation"
            ]
        }
    ]

}
